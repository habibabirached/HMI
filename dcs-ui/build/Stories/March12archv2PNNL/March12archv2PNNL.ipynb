# %% [markdown]
# The HMI will be shown for the Meta visit, correct? I had a call with CS today about what their plans were for showing them the models, so maybe we can keep what we show consistent. I've created a new file with the latest simulation results. It still has one of the same tabs as before, but also another configuration. Not much has changed, just that there are now 4 generators and 2 loads.
# Story 1: 1/4 block system with load measurements. The excel sheet is QuarterBlock_Load.
#
#  ![twoLMs configuration](./twoLMs.png)

# %%
Plot 1 (active power (MW)): x = Time, y = active power (columns B-E)
Plot 2 (reactive power (MVar): x = Time (s), y reactive power (columns F-I)
Plot 3 (voltage (p.u.)): x = Time (s), y = voltage (columns J-M)
Plot 4 (frequency (Hz)): x = Time (s), y = frequency (column N)
Plot 5 (load instantaneous voltage): x = Time (s), y = columns O-Z. For this one, each of the voltages are three phase signals, so I am not sure the best way to represent them. Maybe you can do them separately or do a stacked graph either split by phase or load, we can look more into it on Monday.
Plot 6 (load active power (MW)): x = Time (s), y = active power (columns AB-AE)
Plot 7 (load reactive power (MVar)): x= Time (s), y reactive power (columns AF-AI)
Plot 8 (total load power vs total generation power): x = Time (s), y = [plot 1 = sum of columns C+D+E][plot2 = column B]
Something like plot 8 is of most interest to consulting services right now, as they are hesitant to show customers the entirety of our commercial models but also do not want to lean too much on generic models. I think those 8 are a good starting point though
Story 2: 1/2 block system with load measurements. The excel sheet is HalfBlock. I will ping you once I add the load measurements in. This is the next step in the system, only difference is we now have 4 generators and a second load

# %% [markdown]
#  ![twoLMs configuration](./fourLMs.png)

# %%
- Plot 1 (active power (MW)): x = Time, y = active power (columns B-H)
Plot 2 (reactive power (MVar): x = Time (s), y reactive power (columns I-O)
Plot 3 (voltage (p.u.)): x = Time (s), y = voltage (columns P-V)
Plot 4 (frequency (Hz)): x = Time (s), y = frequency (column W)
Plot 5 (load instantaneous voltage): x = Time (s), y = columns x. For this one, each of the voltages are three phase signals, so I am not sure the best way to represent them. Maybe you can do them separately or do a stacked graph either split by phase or load, we can look more into it on Monday.
Plot 6 (load active power (MW)): x = Time (s), y = active power (columns x)
Plot 7 (load reactive power (MVar)): x= Time (s), y reactive power (columns x)
Plot 8 (total load power vs total generation power): x = Time (s), y = [plot 1 = sum of columns C+D+E+G+H][plot2 = column B+F]
